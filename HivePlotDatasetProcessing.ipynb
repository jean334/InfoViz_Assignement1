# %% [markdown]
# # This notebook aims at preparing the data for the Hive Plot visualisation

# %% [markdown]
# ## Importing the libraries

# %%
import json
from urllib.parse import unquote

# %% [markdown]
# ## Retrieving all Wikipedia's articles
#
# Wikipedia's articles are in the file articles.tsv, every row contains an URL encoded article

# %%
with open('Wikipedia/wikispeedia_paths-and-graph/wikispeedia_paths-and-graph/articles.tsv', 'r') as f:
    entries = f.readlines()

all_entries = []

for i in range(len(entries)):
    entry = unquote(entries[i])
    entry = entry.split('\n')[0]
    if entry not in all_entries:
        all_entries.append(entry)

print(all_entries[:10])
# Out:
# ['Áedán_mac_Gabráin', 'Åland', 'Édouard_Manet', 'Éire', 'Óengus_I_of_the_Picts', '€2_commemorative_coins', '10th_century', '11th_century', '12th_century', '13th_century']

# %% [markdown]
# ## Computing the radius of every node and links between them
#
# The file `paths_finished.tsv` contains starting and ending articles for every completed wikispeedia game, articles that lead to the final article are seperated by semicolon ";", thus, they are linked together. Sometimes, player went back to the previous link, which is denoted as "<", those links are ignored

# %%
with open('Wikipedia/wikispeedia_paths-and-graph/wikispeedia_paths-and-graph/paths_finished.tsv', 'r') as f:
    path = f.readlines()

data_json = {"nodes": [], "links": []}

for i in range(len(all_entries)):
    data_json["nodes"].append({"id": all_entries[i], "group": [], "sub_group": '', "radius": 5})

data_json["nodes"] = {node['id']: node for node in data_json["nodes"]}

for i in range(len(path)):
    chemin = path[i].split('\t')
    entries_in_path = chemin[3].split(";")
    entries_in_path = [unquote(e) for e in entries_in_path]
    for i in range(len(entries_in_path)-1):
        if entries_in_path[i] != "<" and entries_in_path[i+1] != "<":
            data_json["nodes"][entries_in_path[i]]["radius"] +=1
            data_json["links"].append({"source": entries_in_path[i], "target": entries_in_path[i+1], "sub_source": '', "sub_taget" : ''})

# %% [markdown]
# ## Retrieving the sub-groups of every groups

# %%
def getSubGroups():
    all_subjects = {}
    association = {}
    for i in range(len(all_entries)):
        association[all_entries[i]] = []
    with open('Wikipedia/wikispeedia_paths-and-graph/wikispeedia_paths-and-graph/categories.tsv', 'r') as f:
        line = f.readlines()

    for l in line:
        elem = l.split('\t')
        entry = elem[0]
        entry = unquote(entry)

        if len(elem) > 1:
            subject = elem[1].split('.')
            if len(subject) >= 3:
                if subject[1] not in all_subjects:
                    all_subjects[subject[1]] = []
                cat = subject[2]

                if cat[-1] == '\n':
                    cat = cat[:-1]
                if cat not in all_subjects[subject[1]]:
                    all_subjects[subject[1]].append(cat)
                association[entry].append(cat)
    return association, all_subjects

association, all_subjects = getSubGroups()
print(all_subjects)
print(association)
# Out:
# {'History': ['British_History', 'General_history', 'Military_History_and_War', 'Recent_History', 'Ancient_History_Classical_History_and_Mythology', 'Pre_1900_Military', 'World_War_II', 'Archaeology', 'Historians_chroniclers_and_history_books', 'North_American_History'], 'People': ['Historical_figures', 'Artists', 'Sports_and_games_people', 'Geographers_and_explorers', 'Writers_and_critics', 'USA_Presidents', 'Religious_figures_and_leaders', 'Political_People', 'Producers_directors_and_media_figures', 'Mathematicians', 'Astronomers_and_physicists', 'Engineers_and_inventors', 'Military_People', 'Chemists', 'Monarchs_of_Great_Britain', 'Actors_models_and_celebrities', 'Performers_and_composers', 'Philosophers', 'Human_Scientists', 'Computing_People'], 'Geography': ['European_Geography', 'Storms', 'Geology_and_geophysics', 'Natural_Disasters', 'Geography_of_the_Middle_East', 'Geography_of_Great_Britain', 'African_Geography', 'Geography_of_Asia', 'General_Geography', 'Geography_of_Oceania_Australasia', 'North_American_Geography', 'Central_and_South_American_Geography', 'Mineralogy', 'Peoples', 'Antarctica', 'Climate_and_the_Weather'], 'Business_Studies': ['Currency', 'Companies', 'Business', 'Economics'], 'Science': ['Physics', 'Biology', 'Chemistry'], 'Everyday_life': ['Sports_events', 'Everyday_life', 'Drink', 'Food_and_agriculture', 'Sports_teams', 'Sports', 'Computer_and_Video_games', 'Films', 'Recreation', 'Television', 'Games', 'Cartoons'], 'Design_and_Technology': ['Railway_transport', 'Air_and_Sea_transport', 'Engineering', 'Architecture', 'Road_transport'], 'Music': ['Performers_and_composers', 'Musical_genres_styles_eras_and_events', 'Musical_Recordings_and_compositions', 'Musical_Instruments'], 'IT': ['Computing_hardware_and_infrastructure', 'Websites_and_the_Internet', 'Computer_Programming', 'Software', 'Cryptography'], 'Language_and_literature': ['Novels', 'Theatre', 'Literature_types', 'Languages', 'Poetry_and_Opera', 'Linguistics', 'General_Literature'], 'Religion': ['Religious_movements_traditions_and_organizations', 'Religious_texts', 'Philosophy', 'Religious_disputes', 'Divinities', 'Myths'], 'Art': ['Art', 'Artists'], 'Citizenship': ['Environment', 'Politics_and_government', 'Media', 'Animal_and_Human_Rights', 'Conflict_and_Peace', 'Community_organisations', 'Law', 'Culture_and_Diversity', 'Education']}
# {'Áedán_mac_Gabráin': ['British_History', 'Historical_figures'], 'Åland': ['European_Geography'], 'Édouard_Manet': ['Artists'], 'Éire': ['European_Geography'], 'Óengus_I_of_the_Picts': ['British_History', 'Historical_figures'], '€2_commemorative_coins': ['Currency'], '10th_century': ['General_history'], '11th_century': ['General_history'], '12th_century': ['General_history'], '13th_century': ['General_history'], '14th_century': ['General_history'], '15th_Marine_Expeditionary_Unit': ['Military_History_and_War'], '15th_century': ['General_history'], '16_Cygni': ['Physics'], '16_Cygni_Bb': ['Physics'], '16th_century': ['General_history'], '1755_Lisbon_earthquake': ['General_history'], '17th_century': ['General_history'], '1896_Summer_Olympics': ['Sports_events'], '18th_century': ['General_history'], '1928_Okeechobee_Hurricane': ['Storms'], '1973_oil_crisis': ['Recent_History'], '1980_eruption_of_Mount_St._Helens': ['Geology_and_geophysics'], '1997_Pacific_hurricane_season': ['Natural_Disasters'], '19th_century': ['General_history'], '1_Ceres': ['Physics'], '1st_century': ['General_history'], '1st_century_BC': ['General_history'], '2-6-0': ['Railway_transport'], '2-8-0': ['Railway_transport'], '2003_Atlantic_hurricane_season': ['Natural_Disasters'], '2004_Atlantic_hurricane_season': ['Natural_Disasters'], '2004_Indian_Ocean_earthquake': ['Geology_and_geophysics'], '2005_Atlantic_hurricane_season': ['Storms'], '2005_Hertfordshire_Oil_Storage_Terminal_fire': ['Recent_History'], '2005_Kashmir_earthquake': ['Natural_Disasters'], '2005_Lake_Tanganyika_earthquake': ['Natural_Disasters'], '2005_Sumatra_earthquake': ['Natural_Disasters'], '20th_century': ['General_history'], '21st_century': ['General_history'], '2nd_century': ['General_history'], '3_Juno': ['Physics'], '3rd_century': ['General_history'], '4-2-0': ['Railway_transport'], '4-4-0': ['Railway_transport'], '4-6-0': ['Railway_transport'], '47_Ursae_Majoris': ['Physics'], '47_Ursae_Majoris_b': ['Physics'], '47_Ursae_Majoris_c': ['Physics'], '4_Vesta': ['Physics'], '4th_century': ['General_history'], '55_Cancri': ['Physics'], '55_Cancri_b': ['Physics'], '55_Cancri_c': ['Physics'], '55_Cancri_d': ['Physics'], '55_Cancri_e': ['Physics'], '5th_century': ['General_history'], '6-2-0': ['Railway_transport'], '6th_century': ['General_history'], '7th_century': ['General_history'], '8th_century': ['General_history'], '90377_Sedna': ['Physics'], '9th_century': ['General_history'], 'A._E._J._Collins': ['Sports_and_games_people'], 'ABO_blood_group_system': ['Biology'], 'AC_DC': ['Performers_and_composers'], 'AIDS': ['Biology'], 'AK-47': ['Military_History_and_War'], 'ALCO_FA': ['Railway_transport'], 'ASCII': ['Computing_hardware_and_infrastructure'], 'AT&T': ['Companies'], 'ATLAS_experiment': ['Physics'], 'A_Christmas_Carol': ['Novels'], 'A_Tale_of_a_Tub': ['Novels'], 'A_Wrinkle_in_Time': ['Novels'], 'A_cappella': ['Musical_genres_styles_eras_and_events'], 'Aachen': ['European_Geography'], 'Aardvark': ['Biology'], 'Aarhus': ['European_Geography'], 'Abacá': ['Biology'], 'Abacus': ['Everyday_life'], 'Abadan': ['Geography_of_the_Middle_East'], 'Abbadid': ['Ancient_History_Classical_History_and_Mythology'], 'Abbas_I_of_Persia': ['Historical_figures'], 'Abbasid': ['Ancient_History_Classical_History_and_Mythology'], 'Abbey': ['British_History', 'Religious_movements_traditions_and_organizations'], 'Abbey_Theatre': ['Theatre'], 'Abbot': ['British_History', 'Religious_movements_traditions_and_organizations'], 'Abel_Tasman': ['Geographers_and_explorers'], 'Aberdeen': ['Geography_of_Great_Britain'], 'Aberration_of_light': ['Physics'], 'Aberystwyth': ['Geography_of_Great_Britain'], 'Abhidhamma_Pitaka': ['Religious_texts'], 'Abidjan': ['African_Geography'], 'Abkhazia': ['Geography_of_Asia'], 'Able_Archer_83': ['Military_History_and_War'], 'Abraham_Goldfaden': ['Writers_and_critics'], 'Abraham_Lincoln': ['USA_Presidents'], 'Absinthe': ['Drink'], 'Absolute_zero': ['Physics'], 'Abstract_art': ['Art'], 'Abu_D ...

# %%
def limitRadius(rad):
    if rad >= 15:
        return 15
    if rad <= 5:
        return 5

# %% [markdown]
# ## Computing the radius of nodes and links between nodes
#
# nodes are sub-groups, they will be placed on axes corresponding to the group they belong to, the radius of the node is porportional to the number of link a node make with other nodes

# %%
import math

data_json_sub = {"nodes": [], "links": []}
for key in all_subjects:
    for sub in all_subjects[key]:
        data_json_sub["nodes"].append({"id": sub, "group": key, "radius": 5})

data_json_sub["nodes"] = {node['id']: node for node in data_json_sub["nodes"]}

for e in data_json["nodes"]:
    for sub in association[e]:
        data_json_sub["nodes"][sub]["radius"] += 1

for e in data_json_sub["nodes"]:
    data_json_sub["nodes"][e]["radius"] = int(math.sqrt(data_json_sub["nodes"][e]["radius"]))


can_append = True
for e in data_json["links"]:
    source = e["source"]
    target = e["target"]
    source_sub = association[source]
    target_sub = association[target]
    for s in source_sub:
        for t in target_sub:
            if s != t:
                for e in all_subjects:
                    if s in all_subjects[e] and t in all_subjects[e]:
                        can_append = False
                        break
                if can_append:
                    data_json_sub["links"].append({"source": s, "target": t})
                can_append = True
            

print(data_json_sub["nodes"])
print(data_json_sub["links"][:10])
# Out:
# {'British_History': {'id': 'British_History', 'group': 'History', 'radius': 12}, 'General_history': {'id': 'General_history', 'group': 'History', 'radius': 9}, 'Military_History_and_War': {'id': 'Military_History_and_War', 'group': 'History', 'radius': 8}, 'Recent_History': {'id': 'Recent_History', 'group': 'History', 'radius': 7}, 'Ancient_History_Classical_History_and_Mythology': {'id': 'Ancient_History_Classical_History_and_Mythology', 'group': 'History', 'radius': 9}, 'Pre_1900_Military': {'id': 'Pre_1900_Military', 'group': 'History', 'radius': 5}, 'World_War_II': {'id': 'World_War_II', 'group': 'History', 'radius': 6}, 'Archaeology': {'id': 'Archaeology', 'group': 'History', 'radius': 4}, 'Historians_chroniclers_and_history_books': {'id': 'Historians_chroniclers_and_history_books', 'group': 'History', 'radius': 3}, 'North_American_History': {'id': 'North_American_History', 'group': 'History', 'radius': 5}, 'Historical_figures': {'id': 'Historical_figures', 'group': 'People', 'radius': 10}, 'Artists': {'id': 'Artists', 'group': 'Art', 'radius': 6}, 'Sports_and_games_people': {'id': 'Sports_and_games_people', 'group': 'People', 'radius': 7}, 'Geographers_and_explorers': {'id': 'Geographers_and_explorers', 'group': 'People', 'radius': 5}, 'Writers_and_critics': {'id': 'Writers_and_critics', 'group': 'People', 'radius': 8}, 'USA_Presidents': {'id': 'USA_Presidents', 'group': 'People', 'radius': 6}, 'Religious_figures_and_leaders': {'id': 'Religious_figures_and_leaders', 'group': 'People', 'radius': 6}, 'Political_People': {'id': 'Political_People', 'group': 'People', 'radius': 8}, 'Producers_directors_and_media_figures': {'id': 'Producers_directors_and_media_figures', 'group': 'People', 'radius': 3}, 'Mathematicians': {'id': 'Mathematicians', 'group': 'People', 'radius': 4}, 'Astronomers_and_physicists': {'id': 'Astronomers_and_physicists', 'group': 'People', 'radius': 5}, 'Engineers_and_inventors': {'id': 'Engineers_and_inventors', 'group': 'People', 'radius': 5}, 'Military_People': {'id': 'Military_People', 'group': 'People', 'radius': 5}, 'Chemists': {'id': 'Chemists', 'group': 'People', 'radius': 3}, 'Monarchs_of_Great_Britain': {'id': 'Monarchs_of_Great_Britain', 'group': 'People', 'radius': 6}, 'Actors_models_and_celebrities': {'id': 'Actors_models_and_celebrities', 'group': 'People', 'radius': 5}, 'Performers_and_composers': {'id': 'Performers_and_composers', 'group': 'Music', 'radius': 8}, 'Philosophers': {'id': 'Philosophers', 'group': 'People', 'radius': 5}, 'Human_Scientists': {'id': 'Human_Scientists', 'group': 'People', 'radius': 5}, 'Computing_People': {'id': 'Computing_People', 'group': 'People', 'radius': 3}, 'European_Geography': {'id': 'European_Geography', 'group': 'Geography', 'radius': 12}, 'Storms': {'id': 'Storms', 'group': 'Geography', 'radius': 6}, 'Geology_and_geophysics': {'id': 'Geology_and_geophysics', 'group': 'Geography', 'radius': 9}, 'Natural_Disasters': {'id': 'Natural_Disasters', 'group': 'Geography', 'radius': 6}, 'Geography_of_the_Middle_East': {'id': 'Geography_of_the_Middle_East', 'group': 'Geography', 'radius': 6}, 'Geography_of_Great_Britain': {'id': 'Geography_of_Great_Britain', 'group': 'Geography', 'radius': 11}, 'African_Geography': {'id': 'African_Geography', 'group': 'Geography', 'radius': 11}, 'Geography_of_Asia': {'id': 'Geography_of_Asia', 'group': 'Geography', 'radius': 10}, 'General_Geography': {'id': 'General_Geography', 'group': 'Geography', 'radius': 8}, 'Geography_of_Oceania_Australasia': {'id': 'Geography_of_Oceania_Australasia', 'group': 'Geography', 'radius': 7}, 'North_American_Geography': {'id': 'North_American_Geography', 'group': 'Geography', 'radius': 10}, 'Central_and_South_American_Geography': {'id': 'Central_and_South_American_Geography', 'group': 'Geography', 'radius': 9}, 'Mineralogy': {'id': 'Mineralogy', 'group': 'Geography', 'radius': 4}, 'Peoples': {'id': 'Peoples', 'group': 'Geography', 'radius': 5}, 'Antarctica': {'id': 'Antarctica', 'group': 'Geograp ...
# [{'source': 'General_history', 'target': 'General_Geography'}, {'source': 'African_Geography', 'target': 'British_History'}, {'source': 'General_history', 'target': 'European_Geography'}, {'source': 'African_Geography', 'target': 'British_History'}, {'source': 'General_history', 'target': 'African_Geography'}, {'source': 'African_Geography', 'target': 'British_History'}, {'source': 'British_History', 'target': 'Animal_and_Human_Rights'}, {'source': 'Animal_and_Human_Rights', 'target': 'African_Geography'}, {'source': 'African_Geography', 'target': 'British_History'}, {'source': 'Ancient_History_Classical_History_and_Mythology', 'target': 'European_Geography'}]

# %% [markdown]
# ## Computing the value of links
#
# the value of link correspond to the number of "sub-link" from one node to another. Sub-group contain a lot of articles that are linked to other articles contained in other nodes.

# %%
data_json_sub2 = {"nodes": [], "links": [{}]}
data_json_sub2["nodes"] = data_json_sub["nodes"]
keys = []

for e in data_json_sub["links"]:
    source = e["source"]
    target = e["target"]
    k = source + "-" + target
    if k not in keys:
        keys.append(k)

dict_links = {}
for k in keys:
    source, target = k.split("-")
    dict_links[k] = {"id": k, "source": source, "target": target, "value": 0}

data_json_sub2["links"] = dict_links

for e in data_json_sub["links"]:
    source = e["source"]
    target = e["target"]
    k = source + "-" + target
    data_json_sub2["links"][k]["value"] += 1

print(data_json_sub2["links"])
# Out:
# {'General_history-General_Geography': {'id': 'General_history-General_Geography', 'source': 'General_history', 'target': 'General_Geography', 'value': 46}, 'African_Geography-British_History': {'id': 'African_Geography-British_History', 'source': 'African_Geography', 'target': 'British_History', 'value': 123}, 'General_history-European_Geography': {'id': 'General_history-European_Geography', 'source': 'General_history', 'target': 'European_Geography', 'value': 469}, 'General_history-African_Geography': {'id': 'General_history-African_Geography', 'source': 'General_history', 'target': 'African_Geography', 'value': 84}, 'British_History-Animal_and_Human_Rights': {'id': 'British_History-Animal_and_Human_Rights', 'source': 'British_History', 'target': 'Animal_and_Human_Rights', 'value': 32}, 'Animal_and_Human_Rights-African_Geography': {'id': 'Animal_and_Human_Rights-African_Geography', 'source': 'Animal_and_Human_Rights', 'target': 'African_Geography', 'value': 51}, 'Ancient_History_Classical_History_and_Mythology-European_Geography': {'id': 'Ancient_History_Classical_History_and_Mythology-European_Geography', 'source': 'Ancient_History_Classical_History_and_Mythology', 'target': 'European_Geography', 'value': 631}, 'European_Geography-Religious_movements_traditions_and_organizations': {'id': 'European_Geography-Religious_movements_traditions_and_organizations', 'source': 'European_Geography', 'target': 'Religious_movements_traditions_and_organizations', 'value': 312}, 'Religious_movements_traditions_and_organizations-Biology': {'id': 'Religious_movements_traditions_and_organizations-Biology', 'source': 'Religious_movements_traditions_and_organizations', 'target': 'Biology', 'value': 61}, 'Biology-USA_Presidents': {'id': 'Biology-USA_Presidents', 'source': 'Biology', 'target': 'USA_Presidents', 'value': 20}, 'USA_Presidents-Politics_and_government': {'id': 'USA_Presidents-Politics_and_government', 'source': 'USA_Presidents', 'target': 'Politics_and_government', 'value': 240}, 'Politics_and_government-USA_Presidents': {'id': 'Politics_and_government-USA_Presidents', 'source': 'Politics_and_government', 'target': 'USA_Presidents', 'value': 672}, 'North_American_Geography-Politics_and_government': {'id': 'North_American_Geography-Politics_and_government', 'source': 'North_American_Geography', 'target': 'Politics_and_government', 'value': 913}, 'General_history-Geography_of_Asia': {'id': 'General_history-Geography_of_Asia', 'source': 'General_history', 'target': 'Geography_of_Asia', 'value': 122}, 'Geography_of_Asia-Chemistry': {'id': 'Geography_of_Asia-Chemistry', 'source': 'Geography_of_Asia', 'target': 'Chemistry', 'value': 70}, 'General_history-Physics': {'id': 'General_history-Physics', 'source': 'General_history', 'target': 'Physics', 'value': 180}, 'Physics-Astronomers_and_physicists': {'id': 'Physics-Astronomers_and_physicists', 'source': 'Physics', 'target': 'Astronomers_and_physicists', 'value': 589}, 'Astronomers_and_physicists-Physics': {'id': 'Astronomers_and_physicists-Physics', 'source': 'Astronomers_and_physicists', 'target': 'Physics', 'value': 342}, 'Physics-Climate_and_the_Weather': {'id': 'Physics-Climate_and_the_Weather', 'source': 'Physics', 'target': 'Climate_and_the_Weather', 'value': 601}, 'General_history-Philosophers': {'id': 'General_history-Philosophers', 'source': 'General_history', 'target': 'Philosophers', 'value': 23}, 'Philosophers-Biology': {'id': 'Philosophers-Biology', 'source': 'Philosophers', 'target': 'Biology', 'value': 82}, 'Physics-Everyday_life': {'id': 'Physics-Everyday_life', 'source': 'Physics', 'target': 'Everyday_life', 'value': 219}, 'Everyday_life-Biology': {'id': 'Everyday_life-Biology', 'source': 'Everyday_life', 'target': 'Biology', 'value': 519}, 'Biology-Climate_and_the_Weather': {'id': 'Biology-Climate_and_the_Weather', 'source': 'Biology', 'target': 'Climate_and_the_Weather', 'value': 362}, 'Climate_and_the_Weather-Physics': {'id': 'Climate_and_the_Weather-Physics', 'source':  ...

# %% [markdown]
# ## Processing the links so that they are not too large

# %%
def limitLinks(value):
    if value > 10:
        return 10
    return value

for e in data_json_sub2["links"]:
    data_json_sub2["links"][e]["value"] = limitLinks(data_json_sub2["links"][e]["value"])

# %%
data_json_sub3 = {"nodes": [], "links": []}

for e in data_json_sub2["links"]:
    data_json_sub3["links"].append(data_json_sub2["links"][e])

for e in data_json_sub2["nodes"]:
    data_json_sub3["nodes"].append(data_json_sub2["nodes"][e])

print(data_json_sub3["links"][:10])
print(data_json_sub3["nodes"][:10])
# Out:
# [{'id': 'General_history-General_Geography', 'source': 'General_history', 'target': 'General_Geography', 'value': 10}, {'id': 'African_Geography-British_History', 'source': 'African_Geography', 'target': 'British_History', 'value': 10}, {'id': 'General_history-European_Geography', 'source': 'General_history', 'target': 'European_Geography', 'value': 10}, {'id': 'General_history-African_Geography', 'source': 'General_history', 'target': 'African_Geography', 'value': 10}, {'id': 'British_History-Animal_and_Human_Rights', 'source': 'British_History', 'target': 'Animal_and_Human_Rights', 'value': 10}, {'id': 'Animal_and_Human_Rights-African_Geography', 'source': 'Animal_and_Human_Rights', 'target': 'African_Geography', 'value': 10}, {'id': 'Ancient_History_Classical_History_and_Mythology-European_Geography', 'source': 'Ancient_History_Classical_History_and_Mythology', 'target': 'European_Geography', 'value': 10}, {'id': 'European_Geography-Religious_movements_traditions_and_organizations', 'source': 'European_Geography', 'target': 'Religious_movements_traditions_and_organizations', 'value': 10}, {'id': 'Religious_movements_traditions_and_organizations-Biology', 'source': 'Religious_movements_traditions_and_organizations', 'target': 'Biology', 'value': 10}, {'id': 'Biology-USA_Presidents', 'source': 'Biology', 'target': 'USA_Presidents', 'value': 10}]
# [{'id': 'British_History', 'group': 'History', 'radius': 12}, {'id': 'General_history', 'group': 'History', 'radius': 9}, {'id': 'Military_History_and_War', 'group': 'History', 'radius': 8}, {'id': 'Recent_History', 'group': 'History', 'radius': 7}, {'id': 'Ancient_History_Classical_History_and_Mythology', 'group': 'History', 'radius': 9}, {'id': 'Pre_1900_Military', 'group': 'History', 'radius': 5}, {'id': 'World_War_II', 'group': 'History', 'radius': 6}, {'id': 'Archaeology', 'group': 'History', 'radius': 4}, {'id': 'Historians_chroniclers_and_history_books', 'group': 'History', 'radius': 3}, {'id': 'North_American_History', 'group': 'History', 'radius': 5}]

# %%
with open(f"D3Viz/netviz/src/assets/Hive.json", "w") as outfile: 
    json.dump(data_json_sub3, outfile)
